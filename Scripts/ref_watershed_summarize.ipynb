# %%
from rasterstats import zonal_stats
import rasterio
import fiona
import geopandas as gpd
import os
import pandas as pd
import glob as glob
import xarray as xr
from osgeo import gdal, osr


home = "/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling"

# %%
ws = gpd.read_file(os.path.join(home, 'Data','Catchments', 'Reference', 'gages_ii', 'reference_keep_4326.shp'))
tifs = [os.path.join(home, "Data", "Topography", "Slope", "slope_10m_sbr.tif"),
        os.path.join(home, "Data", "Topography", "Elevation", "elevation_10m_sbr.tif"),
        os.path.join(home, "Data", "Topography", "Aspect", "aspect_10m_sbr.tif"), 
        os.path.join(home, "Data", "latitude.tif"), 
        os.path.join(home, "Data", "Climate", "tifs", "climatology_prcp_AMJJA.tif"), 
        os.path.join(home, "Data", "Climate", "tifs", "climatology_tmin_AMJJA.tif"), 
        os.path.join(home, "Data", "Climate", "tifs", "climatology_tmax_AMJJA.tif"), 
        os.path.join(home, "Data", "Climate", "tifs", "climatology_vp_AMJJA.tif"), 
        os.path.join(home, "Data", "Climate", "tifs", "climatology_vpd_AMJJA.tif"), 
        os.path.join(home, "Data", "Climate", "tifs", "climatology_par_AMJJA.tif")]
colnames = ["Slope", "Elevation", "Aspect", "Latitude", "Prcp", "Tmin", "Tmax", "VP", "VPD", "PAR"]

K = -1
for tif in tifs:
        print(tif)
        K +=1
        checkcrs = rasterio.open(tif)
        ws = ws.to_crs(checkcrs.crs)
        ws_stats = zonal_stats(ws, tif, all_touched=True, stats='mean')
        ws_stats = pd.DataFrame(ws_stats)
        ws_stats.columns = [colnames[K]]

        if K == 0:
                df = pd.concat([ws['GAGE_ID'], ws_stats], axis=1)
                all_df = df
        if K > 0:
                all_df = pd.concat([all_df, ws_stats], axis=1)
# Out:
# /Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Topography/Slope/slope_10m_sbr.tif
# /Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Topography/Elevation/elevation_10m_sbr.tif
# /Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Topography/Aspect/aspect_10m_sbr.tif
# /Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/latitude.tif
# /Users/katiemcquillan/opt/anaconda3/envs/ch2-python-env/lib/python3.9/site-packages/rasterstats/io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")
# /Users/katiemcquillan/opt/anaconda3/envs/ch2-python-env/lib/python3.9/site-packages/rasterstats/io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")
# ...

# %%
all_df
# Out:
#        GAGE_ID      Slope    Elevation      Aspect   Latitude        Prcp  \
# 0     02053800  17.616016   709.849758  191.306558  37.207957  561.619327
# 1     02056900  12.791029   467.268477  174.971041  37.171160  575.679097
# 2     02069700  13.424054   451.195054  176.572567  36.827728  620.718562
# 3     02070000   9.886490   333.121330  180.940980  36.853430  580.726171
# 4     02111180  21.927279   633.861321  171.745947  36.444965  664.973704
# 5     02111500  17.722950   557.762953  175.415937  36.544928  628.869811
# 6     02112120  16.026022   531.776003  179.859004  36.603216  618.878561
# 7     02112360  13.432250   478.838773  174.333459  36.649776  600.635687
# 8     02118500   8.446852   357.774873  173.006462  36.391192  620.124150
# 9     02137727  20.076731   650.232031  172.918615  36.034480  680.335850
# 10    02140991  20.314544   624.511760  174.449770  36.326521  661.584748
# 11    02142000  12.258361   428.273305  177.342587  36.320965  638.536770
# ...

# %%
all_df.to_csv(os.path.join(home, "Data", "Catchments", "Reference", "gages_ii", "summarize_ws_vars.csv"))

# %% [markdown]
# ### I want to summarize annual precipitation on the water year (October - September) for each reference watreshed

# %%
# create tifs of water year total precipitation 
# template for tifs 
template = "/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/template.tif"

ds = gdal.Open(template)
wkt = ds.GetProjection()
trans = ds.GetGeoTransform()
cols = ds.RasterXSize
rows = ds.RasterYSize   

years =  range(1985, 2022) # grabs up to 2020 
files = glob.glob(os.path.join(home, "Data", "Climate",  "prcp*.nc"))

names = [os.path.basename(x) for x in files]
file_year = [int(x[-13:-9]) for x in names]
files = [x for _, x in sorted(zip(file_year, files))]   
K = -1 

for year in years: 
    K += 1 
    file = files[K:(K+2)]
    print(K)
    print(year)
    print(file)

    dsp = xr.open_mfdataset(file)
    water_year = (dsp.time.dt.month >= 10) + dsp.time.dt.year
    dsp.coords['water_year'] = water_year
    dsp = dsp['prcp'].sel(time=(dsp.water_year == year))
    ds_wy = dsp.sum('time')
    myslice = ds_wy.to_numpy()
    outpath = os.path.join(home, "Data", "Climate", "tifs", "prcp_wy", "prcp_" + str(year) + ".tif")

    driver = ds.GetDriver()
    outDs = driver.Create(outpath, cols, rows, 1, gdal.GDT_Float32)
    outBand = outDs.GetRasterBand(1)
    outBand.WriteArray(myslice)
    outDs.SetGeoTransform(trans)    
    srs = osr.SpatialReference()
    srs.ImportFromWkt(wkt)
    outDs.SetProjection(srs.ExportToWkt())

    outDs = None
# Out:
# 0
# 1985
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1984subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1985subset.nc']
# 1
# 1986
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1985subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1986subset.nc']
# 2
# 1987
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1986subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1987subset.nc']
# 3
# 1988
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1987subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1988subset.nc']
# 4
# 1989
# ...

# %%
# calculate the average precipitation for each reference watershed x year 
ws = gpd.read_file(os.path.join(home, 'Data','Catchments', 'Reference', 'gages_ii', 'reference_keep_4326.shp'))
tifs = glob.glob(os.path.join(home, "Data", "Climate", "tifs", "prcp_wy", "*.tif"))

file_year = [int(os.path.basename(x)[-8:-4]) for x in tifs]
tifs = [x for _, x in sorted(zip(file_year, tifs))]   
colnames = file_year

K = -1
for tif in tifs:
        print(tif)
        K +=1
        checkcrs = rasterio.open(tif)
        ws = ws.to_crs(checkcrs.crs)
        ws_stats = zonal_stats(ws, tif, all_touched=True, stats='mean')
        ws_stats = pd.DataFrame(ws_stats)
        ws_stats.columns = [str(colnames[K])]

        if K == 0:
                df = pd.concat([ws['GAGE_ID'], ws_stats], axis=1)
                all_df = df
        if K > 0:
                all_df = pd.concat([all_df, ws_stats], axis=1)
# Out:
# /Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tifs/prcp_wy/prcp_1985.tif
# /Users/katiemcquillan/opt/anaconda3/envs/ch2-python-env/lib/python3.9/site-packages/rasterstats/io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")
# /Users/katiemcquillan/opt/anaconda3/envs/ch2-python-env/lib/python3.9/site-packages/rasterstats/io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")
# /Users/katiemcquillan/opt/anaconda3/envs/ch2-python-env/lib/python3.9/site-packages/rasterstats/io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")
# ...

# %%
all_df.to_csv(os.path.join(home, "Data", "Climate","Summary", "ref_watersheds_wy_precipitation.csv"))

# %% [markdown]
# ## VEG WATER YEAR

# %%
# summarize precipiation over the vegetation water year (june - may)

# create tifs of water year total precipitation 
# template for tifs 
template = "/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/template.tif"

ds = gdal.Open(template)
wkt = ds.GetProjection()
trans = ds.GetGeoTransform()
cols = ds.RasterXSize
rows = ds.RasterYSize   

years =  range(1984, 2021) # grabs up to 2020
files = glob.glob(os.path.join(home, "Data", "Climate",  "prcp*.nc"))

names = [os.path.basename(x) for x in files]
file_year = [int(x[-13:-9]) for x in names]
files = [x for _, x in sorted(zip(file_year, files))]   
K = -1 

for year in years: 
    K += 1 
    file = files[K:(K+2)]
    print(K)
    print(year)
    print(file)

    dsp = xr.open_mfdataset(file)
    water_year = (dsp.time.dt.month >= 6) + dsp.time.dt.year
    dsp.coords['water_year'] = water_year
    dsp = dsp['prcp'].sel(time=(dsp.water_year == (year+1)))
    ds_wy = dsp.sum('time')
    myslice = ds_wy.to_numpy()
    outpath = os.path.join(home, "Data", "Climate", "tifs", "prcp_veg_wy", "prcp_" + str(year + 1) + ".tif")

    driver = ds.GetDriver()
    outDs = driver.Create(outpath, cols, rows, 1, gdal.GDT_Float32)
    outBand = outDs.GetRasterBand(1)
    outBand.WriteArray(myslice)
    outDs.SetGeoTransform(trans)    
    srs = osr.SpatialReference()
    srs.ImportFromWkt(wkt)
    outDs.SetProjection(srs.ExportToWkt())

    outDs = None
# Out:
# 0
# 1984
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1984subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1985subset.nc']
# 1
# 1985
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1985subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1986subset.nc']
# 2
# 1986
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1986subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1987subset.nc']
# 3
# 1987
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1987subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1988subset.nc']
# 4
# 1988
# ...

# %%
# calculate the average precipitation for each reference watershed x year 
ws = gpd.read_file(os.path.join(home, 'Data','Catchments', 'Reference', 'gages_ii', 'reference_keep_4326.shp'))
tifs = glob.glob(os.path.join(home, "Data", "Climate", "tifs", "prcp_veg_wy", "*.tif"))

file_year = [int(os.path.basename(x)[-8:-4]) for x in tifs]
tifs = [x for _, x in sorted(zip(file_year, tifs))]   
colnames = file_year

K = -1
for tif in tifs:
        print(tif)
        K +=1
        checkcrs = rasterio.open(tif)
        ws = ws.to_crs(checkcrs.crs)
        ws_stats = zonal_stats(ws, tif, all_touched=True, stats='mean')
        ws_stats = pd.DataFrame(ws_stats)
        ws_stats.columns = [str(colnames[K])]

        if K == 0:
                df = pd.concat([ws['GAGE_ID'], ws_stats], axis=1)
                all_df = df
        if K > 0:
                all_df = pd.concat([all_df, ws_stats], axis=1)
# Out:
# /Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tifs/prcp_veg_wy/prcp_1985.tif
# /Users/katiemcquillan/opt/anaconda3/envs/ch2-python-env/lib/python3.9/site-packages/rasterstats/io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")
# /Users/katiemcquillan/opt/anaconda3/envs/ch2-python-env/lib/python3.9/site-packages/rasterstats/io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")
# /Users/katiemcquillan/opt/anaconda3/envs/ch2-python-env/lib/python3.9/site-packages/rasterstats/io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")
# ...

# %%
all_df.to_csv(os.path.join(home, "Data", "Climate","Summary", "ref_watersheds_veg_wy_precipitation.csv"))
