# %%
import os
import geopandas as gpd
from glob import glob
import numpy as np
import pandas as pd 
import rasterio 
from rasterio.merge import merge
from rasterio.plot import show
from rasterio.mask import mask
import matplotlib.pyplot as plt
import shutil
import sys
import xarray as xr
from osgeo import gdal, osr

home = "/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling"
exec(open(os.path.join(home, "Scripts", "Functions.py")).read())

# python -m pip install "xarray[complete]"
# https://colab.research.google.com/drive/1B7gFBSr0eoZ5IbsA0lY8q3XL8n-3BOn4#scrollTo=1I_gUeqs5Sak

# %%
def climate_anomalies(VAR, agg):

    years =  range(1985, 2022) # grabs up to 2020 
    files = glob(os.path.join(home, "Data", "Climate", VAR + "*.nc"))
    # order the files by year 
    names = [os.path.basename(x) for x in files]
    file_year = [int(x[-13:-9]) for x in names]
    files = [x for _, x in sorted(zip(file_year, files))]   
    K = -1 
    for year in years: 
        K += 1 
        file = files[K:(K+2)]
        print(K)
        print(year)
        print(file)
        ds = xr.open_mfdataset(file)
        water_year = (ds.time.dt.month >= 9) + ds.time.dt.year
        ds.coords['water_year'] = water_year
        ds = ds[VAR].sel(time=(ds.water_year == year))
    
        if agg == 'mean':
            if K == 0: 
                ds_wy = ds.mean('time')
                ds_son = ds.sel(time = np.isin(ds.time.dt.month, [9,10,11])).mean('time')
                ds_djf = ds.sel(time = np.isin(ds.time.dt.month, [12,1,2])).mean('time')
                ds_mam = ds.sel(time = np.isin(ds.time.dt.month, [3,4,5])).mean('time')
                ds_jja = ds.sel(time = np.isin(ds.time.dt.month, [6,7,8])).mean('time')
                ds_mamjja = ds.sel(time = np.isin(ds.time.dt.month, [3,4,5,6,7,8])).mean('time')
            else: 
                ds_wy = xr.concat([ds_wy, ds.mean('time')], dim='year')
                ds_son = xr.concat([ds_son, ds.sel(time = np.isin(ds.time.dt.month, [9,10,11])).mean('time')], dim='year')
                ds_djf = xr.concat([ds_djf, ds.sel(time = np.isin(ds.time.dt.month, [12,1,2])).mean('time')], dim='year')
                ds_mam = xr.concat([ds_mam, ds.sel(time = np.isin(ds.time.dt.month, [3,4,5])).mean('time')], dim='year')
                ds_jja = xr.concat([ds_jja, ds.sel(time = np.isin(ds.time.dt.month, [6,7,8])).mean('time')], dim='year')
                ds_mamjja = xr.concat([ds_mamjja, ds.sel(time = np.isin(ds.time.dt.month, [3,4,5,6,7,8])).mean('time')], dim='year')
    
        if agg == 'sum':
            if K == 0: 
                ds_wy = ds.sum('time')
                ds_son = ds.sel(time = np.isin(ds.time.dt.month, [9,10,11])).sum('time')
                ds_djf = ds.sel(time = np.isin(ds.time.dt.month, [12,1,2])).sum('time')
                ds_mam = ds.sel(time = np.isin(ds.time.dt.month, [3,4,5])).sum('time')
                ds_jja = ds.sel(time = np.isin(ds.time.dt.month, [6,7,8])).sum('time')
                ds_mamjja = ds.sel(time = np.isin(ds.time.dt.month, [3,4,5,6,7,8])).sum('time')
            else: 
                ds_wy = xr.concat([ds_wy, ds.sum('time')], dim='year')
                ds_son = xr.concat([ds_son, ds.sel(time = np.isin(ds.time.dt.month, [9,10,11])).sum('time')], dim='year')
                ds_djf = xr.concat([ds_djf, ds.sel(time = np.isin(ds.time.dt.month, [12,1,2])).sum('time')], dim='year')
                ds_mam = xr.concat([ds_mam, ds.sel(time = np.isin(ds.time.dt.month, [3,4,5])).sum('time')], dim='year')
                ds_jja = xr.concat([ds_jja, ds.sel(time = np.isin(ds.time.dt.month, [6,7,8])).sum('time')], dim='year')
                ds_mamjja = xr.concat([ds_mamjja, ds.sel(time = np.isin(ds.time.dt.month, [3,4,5,6,7,8])).sum('time')], dim='year')

    # calculate anomalies and water year climatology 
    ds_wy_anomalies = (ds_wy - ds_wy.mean('year'))/ds_wy.std('year')
    ds_son_anomalies = (ds_son - ds_son.mean('year'))/ds_son.std('year')
    ds_djf_anomalies = (ds_djf - ds_djf.mean('year'))/ds_djf.std('year')
    ds_mam_anomalies = (ds_mam - ds_mam.mean('year'))/ds_mam.std('year')
    ds_jja_anomalies = (ds_jja - ds_jja.mean('year'))/ds_jja.std('year')
    ds_mamjja_anomalies = (ds_mamjja - ds_mamjja.mean('year'))/ds_mamjja.std('year')
    climatology = ds_wy.mean('year')

    # save the anomalies and water year climatology to a .nc
    ds_wy_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", VAR + "_WY.nc"))
    ds_son_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", VAR + "_SON.nc"))
    ds_djf_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", VAR + "_DJF.nc"))
    ds_mam_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", VAR + "_MAM.nc"))
    ds_jja_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", VAR + "_JJA.nc"))
    ds_mamjja_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", VAR + "_MAMJJA.nc"))
    climatology.to_netcdf(path = os.path.join(home, "Data", "Climate", "climatology", VAR + "_WY.nc"))

# %%
climate_anomalies("tmin", "mean")
climate_anomalies("tmax", "mean")
climate_anomalies("prcp", "sum")
climate_anomalies("vp", "mean")
# Out:
# 0
# 1985
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1984subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1985subset.nc']
# 1
# 1986
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1985subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1986subset.nc']
# 2
# 1987
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1986subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1987subset.nc']
# 3
# 1988
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1987subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1988subset.nc']
# 4
# 1989
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1988subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1989subset.nc']
# 5
# 1990
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1989subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1990subset.nc']
# 6
# 1991
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1990subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1991subset.nc']
# 7
# 1992
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1991subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1992subset.nc']
# 8
# 1993
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1992subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1993subset.nc']
# 9
# 1994
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1993subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1994subset.nc']
# 10
# 1995
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1994subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1995subset.nc']
# 11
# 1996
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1995subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1996subset.nc']
# 12
# 1997
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1996subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1997subset.nc']
# 13
# 1998
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1997subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1998subset.nc']
# 14
# 1999
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1998subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1999subset.nc']
# 15
# 2000
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_1999subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2000subset.nc']
# 16
# 2001
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2000subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2001subset.nc']
# 17
# 2002
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2001subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2002subset.nc']
# 18
# 2003
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2002subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2003subset.nc']
# 19
# 2004
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2003subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2004subset.nc']
# 20
# 2005
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2004subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2005subset.nc']
# 21
# 2006
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2005subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2006subset.nc']
# 22
# 2007
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2006subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2007subset.nc']
# 23
# 2008
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2007subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2008subset.nc']
# 24
# 2009
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2008subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2009subset.nc']
# 25
# 2010
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2009subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2010subset.nc']
# 26
# 2011
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2010subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2011subset.nc']
# 27
# 2012
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2011subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2012subset.nc']
# 28
# 2013
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2012subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2013subset.nc']
# 29
# 2014
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2013subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2014subset.nc']
# 30
# 2015
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2014subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2015subset.nc']
# 31
# 2016
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2015subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2016subset.nc']
# 32
# 2017
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2016subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2017subset.nc']
# 33
# 2018
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2017subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2018subset.nc']
# 34
# 2019
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2018subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2019subset.nc']
# 35
# 2020
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2019subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2020subset.nc']
# 36
# 2021
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2020subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmin_2021subset.nc']
# 0
# 1985
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1984subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1985subset.nc']
# 1
# 1986
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1985subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1986subset.nc']
# 2
# 1987
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1986subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1987subset.nc']
# 3
# 1988
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1987subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1988subset.nc']
# 4
# 1989
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1988subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1989subset.nc']
# 5
# 1990
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1989subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1990subset.nc']
# 6
# 1991
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1990subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1991subset.nc']
# 7
# 1992
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1991subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1992subset.nc']
# 8
# 1993
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1992subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1993subset.nc']
# 9
# 1994
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1993subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1994subset.nc']
# 10
# 1995
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1994subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1995subset.nc']
# 11
# 1996
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1995subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1996subset.nc']
# 12
# 1997
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1996subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1997subset.nc']
# 13
# 1998
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1997subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1998subset.nc']
# 14
# 1999
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1998subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1999subset.nc']
# 15
# 2000
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_1999subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2000subset.nc']
# 16
# 2001
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2000subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2001subset.nc']
# 17
# 2002
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2001subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2002subset.nc']
# 18
# 2003
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2002subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2003subset.nc']
# 19
# 2004
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2003subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2004subset.nc']
# 20
# 2005
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2004subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2005subset.nc']
# 21
# 2006
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2005subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2006subset.nc']
# 22
# 2007
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2006subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2007subset.nc']
# 23
# 2008
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2007subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2008subset.nc']
# 24
# 2009
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2008subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2009subset.nc']
# 25
# 2010
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2009subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2010subset.nc']
# 26
# 2011
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2010subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2011subset.nc']
# 27
# 2012
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2011subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2012subset.nc']
# 28
# 2013
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2012subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2013subset.nc']
# 29
# 2014
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2013subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2014subset.nc']
# 30
# 2015
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2014subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2015subset.nc']
# 31
# 2016
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2015subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2016subset.nc']
# 32
# 2017
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2016subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2017subset.nc']
# 33
# 2018
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2017subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2018subset.nc']
# 34
# 2019
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2018subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2019subset.nc']
# 35
# 2020
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2019subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2020subset.nc']
# 36
# 2021
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2020subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/tmax_2021subset.nc']
# 0
# 1985
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1984subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1985subset.nc']
# 1
# 1986
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1985subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1986subset.nc']
# 2
# 1987
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1986subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1987subset.nc']
# 3
# 1988
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1987subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1988subset.nc']
# 4
# 1989
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1988subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1989subset.nc']
# 5
# 1990
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1989subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1990subset.nc']
# 6
# 1991
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1990subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1991subset.nc']
# 7
# 1992
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1991subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1992subset.nc']
# 8
# 1993
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1992subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1993subset.nc']
# 9
# 1994
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1993subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1994subset.nc']
# 10
# 1995
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1994subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1995subset.nc']
# 11
# 1996
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1995subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1996subset.nc']
# 12
# 1997
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1996subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1997subset.nc']
# 13
# 1998
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1997subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1998subset.nc']
# 14
# 1999
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1998subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1999subset.nc']
# 15
# 2000
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1999subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2000subset.nc']
# 16
# 2001
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2000subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2001subset.nc']
# 17
# 2002
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2001subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2002subset.nc']
# 18
# 2003
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2002subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2003subset.nc']
# 19
# 2004
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2003subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2004subset.nc']
# 20
# 2005
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2004subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2005subset.nc']
# 21
# 2006
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2005subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2006subset.nc']
# 22
# 2007
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2006subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2007subset.nc']
# 23
# 2008
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2007subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2008subset.nc']
# 24
# 2009
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2008subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2009subset.nc']
# 25
# 2010
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2009subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2010subset.nc']
# 26
# 2011
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2010subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2011subset.nc']
# 27
# 2012
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2011subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2012subset.nc']
# 28
# 2013
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2012subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2013subset.nc']
# 29
# 2014
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2013subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2014subset.nc']
# 30
# 2015
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2014subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2015subset.nc']
# 31
# 2016
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2015subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2016subset.nc']
# 32
# 2017
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2016subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2017subset.nc']
# 33
# 2018
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2017subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2018subset.nc']
# 34
# 2019
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2018subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2019subset.nc']
# 35
# 2020
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2019subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2020subset.nc']
# 36
# 2021
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2020subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_2021subset.nc']
# 0
# 1985
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1984subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1985subset.nc']
# 1
# 1986
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1985subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1986subset.nc']
# 2
# 1987
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1986subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1987subset.nc']
# 3
# 1988
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1987subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1988subset.nc']
# 4
# 1989
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1988subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1989subset.nc']
# 5
# 1990
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1989subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1990subset.nc']
# 6
# 1991
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1990subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1991subset.nc']
# 7
# 1992
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1991subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1992subset.nc']
# 8
# 1993
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1992subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1993subset.nc']
# 9
# 1994
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1993subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1994subset.nc']
# 10
# 1995
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1994subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1995subset.nc']
# 11
# 1996
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1995subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1996subset.nc']
# 12
# 1997
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1996subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1997subset.nc']
# 13
# 1998
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1997subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1998subset.nc']
# 14
# 1999
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1998subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1999subset.nc']
# 15
# 2000
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_1999subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2000subset.nc']
# 16
# 2001
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2000subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2001subset.nc']
# 17
# 2002
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2001subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2002subset.nc']
# 18
# 2003
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2002subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2003subset.nc']
# 19
# 2004
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2003subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2004subset.nc']
# 20
# 2005
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2004subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2005subset.nc']
# 21
# 2006
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2005subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2006subset.nc']
# 22
# 2007
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2006subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2007subset.nc']
# 23
# 2008
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2007subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2008subset.nc']
# 24
# 2009
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2008subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2009subset.nc']
# 25
# 2010
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2009subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2010subset.nc']
# 26
# 2011
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2010subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2011subset.nc']
# 27
# 2012
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2011subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2012subset.nc']
# 28
# 2013
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2012subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2013subset.nc']
# 29
# 2014
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2013subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2014subset.nc']
# 30
# 2015
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2014subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2015subset.nc']
# 31
# 2016
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2015subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2016subset.nc']
# 32
# 2017
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2016subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2017subset.nc']
# 33
# 2018
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2017subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2018subset.nc']
# 34
# 2019
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2018subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2019subset.nc']
# 35
# 2020
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2019subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2020subset.nc']
# 36
# 2021
# ['/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2020subset.nc', '/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/vp_2021subset.nc']

# %%
# calculate dry day anomalies 
def count_dry_days(x): 
    return len(x[np.where(x <= 0.25)])
    
files = glob(os.path.join(home, "Data", "Climate", "prcp*.nc"))
names = [os.path.basename(x) for x in files]
file_year = [int(x[-13:-9]) for x in names]
files = [x for _, x in sorted(zip(file_year, files))]   
years = range(1985, 2022) 
K = -1
for year in years: 
    K += 1 
    file = files[K:(K+2)]
    ds = xr.open_mfdataset(file).load()
    water_year = (ds.time.dt.month >= 9) + ds.time.dt.year
    ds.coords['water_year'] = water_year
    ds = ds['prcp'].sel(time=(ds.water_year == year))
    
    if K == 0: 
        ds_wy = xr.apply_ufunc(count_dry_days, ds, input_core_dims=[["time"]], vectorize=True)
        ds_son = xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [9,10,11])), input_core_dims=[["time"]], vectorize=True)
        ds_djf = xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [12,1,2])), input_core_dims=[["time"]], vectorize=True)
        ds_mam= xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [3,4,5])), input_core_dims=[["time"]], vectorize=True)
        ds_jja = xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [6,7,8])), input_core_dims=[["time"]], vectorize=True)        
        ds_mamjja = xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [3,4,5,6,7,8])), input_core_dims=[["time"]], vectorize=True)

    else:
        ds_wy = xr.concat([ds_wy, xr.apply_ufunc(count_dry_days, ds, input_core_dims=[["time"]], vectorize=True)], dim ='year')
        ds_son = xr.concat([ds_son, xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [9,10,11])), input_core_dims=[["time"]], vectorize=True)], dim='year')
        ds_djf = xr.concat([ds_djf, xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [12,1,2])), input_core_dims=[["time"]], vectorize=True)], dim='year')
        ds_mam = xr.concat([ds_mam, xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [3,4,5])), input_core_dims=[["time"]], vectorize=True)], dim='year')
        ds_jja = xr.concat([ds_jja, xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [6,7,8])), input_core_dims=[["time"]], vectorize=True)], dim='year')
        ds_mamjja = xr.concat([ds_mamjja, xr.apply_ufunc(count_dry_days, ds.sel(time = np.isin(ds.time.dt.month, [3,4,5,6,7,8])), input_core_dims=[["time"]], vectorize=True)], dim='year')

# calculate anomalies and water year climatology 
ds_wy_anomalies = (ds_wy - ds_wy.mean('year'))/ds_wy.std('year')
ds_son_anomalies = (ds_son - ds_son.mean('year'))/ds_son.std('year')
ds_djf_anomalies = (ds_djf - ds_djf.mean('year'))/ds_djf.std('year')
ds_mam_anomalies = (ds_mam - ds_mam.mean('year'))/ds_mam.std('year')
ds_jja_anomalies = (ds_jja - ds_jja.mean('year'))/ds_jja.std('year')
ds_mamjja_anomalies = (ds_mamjja - ds_mamjja.mean('year'))/ds_mamjja.std('year')
climatology = ds_wy.mean('year')

# save the anomalies and water year climatology to a .nc
ds_wy_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", "drydays" + "_WY.nc"))
ds_son_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", "drydays" + "_SON.nc"))
ds_djf_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", "drydays" + "_DJF.nc"))
ds_mam_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", "drydays" + "_MAM.nc"))
ds_jja_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", "drydays" + "_JJA.nc"))
ds_mamjja_anomalies.to_netcdf(path = os.path.join(home, "Data", "Climate", "anomalies", "drydays" + "_MAMJJA.nc"))
climatology.to_netcdf(path = os.path.join(home, "Data", "Climate", "climatology", "drydays" + "_WY.nc"))

# %%
# convert nc files to tifs 
def nc_to_tif(nc, template):
    # nc is the netcdf filepath i want to write to tifs
    # ds is the template raster filepath that i will write the nc files to match 

    # template 
    ds = gdal.Open(template)
    wkt = ds.GetProjection()
    trans = ds.GetGeoTransform()
    cols = ds.RasterXSize
    rows = ds.RasterYSize   
    
    mync = xr.open_dataset(nc)
    myarray = mync.to_array()
    myarray = myarray.to_numpy()
    if len(myarray.shape)==4:
        myarray = myarray[0,:,:,:]
    
    K = 1984
    for time in range(0, myarray.shape[0]):
        K +=1
        myslice = myarray[time,:,:]

        # create the output image
        if len(range(0, myarray.shape[0])) == 1:
            breakdown_path = nc.split("/")
            outname = breakdown_path[len(breakdown_path)-2] + "_" + breakdown_path[len(breakdown_path)-1][:-3] + ".tif"
            outpath = os.path.join(home, "Data", "Climate", "tifs", outname)
        else:
            breakdown_path = nc.split("/")
            outname = breakdown_path[len(breakdown_path)-2] + "_" + breakdown_path[len(breakdown_path)-1][:-3] + "_" + str(K) + ".tif"
            outpath = os.path.join(home, "Data", "Climate", "tifs", outname)

        driver = ds.GetDriver()
        outDs = driver.Create(outpath, cols, rows, 1, gdal.GDT_Float32)
        outBand = outDs.GetRasterBand(1)
        outBand.WriteArray(myslice)
        outDs.SetGeoTransform(trans)    
        srs = osr.SpatialReference()
        srs.ImportFromWkt(wkt)
        outDs.SetProjection(srs.ExportToWkt())

        outDs = None

# %%
# make a raster template 
# template = rxr.open_rasterio('/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/prcp_1984subset.nc')
# template['prcp'].rio.to_raster('/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/template.tif')
template = "/Volumes/GoogleDrive/My Drive/Chapter2_mechanisms_forest_water_cycling/Data/Climate/template.tif"
climatology_nc = glob(os.path.join(home, "Data", "Climate", "climatology", "*.nc"))
anomalies_nc = glob(os.path.join(home, "Data", "Climate", "anomalies", "*.nc"))
all_nc = climatology_nc + anomalies_nc

for nc in all_nc:
    nc_to_tif(nc, template)

# %%
# make a shapefile of the permanent forest in the crs matching the climate data 
import rioxarray as rxr
import rasterio as rio

crs = rio.open(glob(os.path.join(home, "Data", "Climate", "tifs", "*" + 'tmin'  + "*.tif"))[0]).crs
shp = gpd.read_file(os.path.join(home, "Data", "Catchments", "Headwater", "headwater_catchments_perm_forest.shp"))
shp = shp.to_crs(crs)
shp.to_file(os.path.join(home, "Data", "Catchments", "Headwater", "headwater_catchments_perm_forest_climate.shp"))
# Out:
# /Users/katiemcquillan/opt/anaconda3/envs/ch2-python-env/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
